# %%
import re
import string
import nltk
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
import gensim

# %%
with open('text.txt', 'r') as f:
    text = f.readlines()

# %%
def prepocess(text):
    return re.sub(r"[^a-zA-Z0-9]+", ' ', re.sub(r'\d+', '', text.lower()).translate(str.maketrans('', '', string.punctuation)).strip())

# %%
a = []
for sent in text:
    a.append(prepocess(sent))

# %%
stop_words = set(stopwords.words('english'))
from nltk.tokenize import word_tokenize
tokens = word_tokenize(str(a))
result = [i for i in tokens if not i in stop_words]

# %%
lemmatizer=WordNetLemmatizer()
preprocess_text = []
for word in result:
    preprocess_text.append(lemmatizer.lemmatize(word))

# %%
pre_token = word_tokenize(str(preprocess_text))

# %%
preprocess_text
# Out:
# ['[',
#  "'lp",
#  "'",
#  ',',
#  "'sphotos",
#  'someone',
#  'smashed',
#  'hell',
#  'dozen',
#  'linknyc',
#  'kiosk',
#  'gothamistnsupport',
#  'usnnypr',
#  'networknnypr',
#  'networkngothamist',
#  'website',
#  'new',
#  'yorknview',
#  'pretty',
#  'blognarts',
#  'entertainmentnfoodnnewsnpopularnwe',
#  'commutersnadvertisingncontactnnewsletternrss',
#  'feednstaffnphotos',
#  'someone',
#  'smashed',
#  'hell',
#  'dozen',
#  'linknyc',
#  'kiosksnby',
#  'jake',
#  'offenhartz',
#  'newstttttttttttttton',
#  'apr',
#  'pmnfullscreenncontinuenview',
#  'fullscreennclosenthe',
#  'war',
#  'man',
#  'machine',
#  'heating',
#  'time',
#  'nothing',
#  'mister',
#  'softeenin',
#  'last',
#  'day',
#  'unidentified',
#  'vandal',
#  'andor',
#  'blade',
#  'runner',
#  'smashed',
#  'least',
#  'linknyc',
#  'kiosk',
#  'west',
#  'village',
#  'chelsea',
#  'leaving',
#  'trail',
#  'destruction',
#  'along',
#  'th',
#  'th',
#  'avenue',
#  'across',
#  'th',
#  'street',
#  'several',
#  'screen',
#  'remained',
#  'black',
#  'monday',
#  'morning',
#  'others',
#  'continued',
#  'display',
#  'standard',
#  'programmingxexxads',
#  'north',
#  'face',
#  'linknycfacts',
#  'ad',
#  'citibank',
#  'etcxexxthrough',
#  'concentric',
#  'circle',
#  'shattered',
#  'glassnobserves',
#  'gothamist',
#  'editorinchief',
#  'john',
#  'del',
#  'signore',
#  'cant',
#  'nice',
#  'dystopian',
#  'capitalist',
#  'data',
#  'harvesting',
#  'thingsnyikes',
#  'somebody',
#  'went',
#  'around',
#  'village',
#  'smashing',
#  'linknyc',
#  'screen',
#  'pictwittercomswdtwltixexx',
#  'josh',
#  'machiz',
#  'machiz',
#  'april',
#  'nafter',
#  'several',
#  'new',
#  'yorkers',
#  'took',
#  'note',
#  'rampage',
#  'online',
#  'spokesperson',
#  'linknyc',
#  'said',
#  'company',
#  'aware',
#  'damage',
#  'looking',
#  'linknyc',
#  'provides',
#  'valuable',
#  'public',
#  'service',
#  'many',
#  'city',
#  'vulnerable',
#  'wrote',
#  'twitter',
#  'people',
#  'vandalize',
#  'link',
#  'impede',
#  'ability',
#  'fund',
#  'deliver',
#  'servicesnbut',
#  'everyone',
#  'see',
#  'way',
#  'mark',
#  'thomasxexxa',
#  'queen',
#  'resident',
#  'year',
#  'protesting',
#  'company',
#  'transforming',
#  'structure',
#  'adhoc',
#  'noise',
#  'machinesxexxtold',
#  'gothamist',
#  'felt',
#  'like',
#  'linknyc',
#  'using',
#  'poor',
#  'pawn',
#  'say',
#  'please',
#  'dont',
#  'smash',
#  'adsnthey',
#  'didnt',
#  'get',
#  'business',
#  'serve',
#  'poor',
#  'vulnerable',
#  'added',
#  'sell',
#  'ad',
#  'make',
#  'lot',
#  'moneynhave',
#  'seen',
#  'linknyc',
#  'vandalized',
#  'blatantly',
#  'side',
#  'th',
#  'th',
#  'th',
#  'pictwittercomqoylqxexx',
#  'dave',
#  'temkin',
#  'dtemkin',
#  'april',
#  'nsince',
#  'launching',
#  'hulking',
#  'tabletsxexxwhich',
#  'number',
#  'roughly',
#  'citywidexexxhave',
#  'faced',
#  'scrutiny',
#  'privacy',
#  'expert',
#  'civil',
#  'liberty',
#  'group',
#  'business',
#  'model',
#  'potential',
#  'surveillance',
#  'overreach',
#  'kiosk',
#  'effectively',
#  'underwritten',
#  'google',
#  'subsidiary',
#  'called',
#  'sidewalk',
#  'lab',
#  'headed',
#  'former',
#  'deputy',
#  'mayor',
#  'hudson',
#  'yardsbooster',
#  'dan',
#  'doctoroff',
#  'privately',
#  'doctoroff',
#  'described',
#  'company',
#  'plan',
#  'track',
#  'pedestrian',
#  'serve',
#  'targeted',
#  'ad',
#  'goal',
#  'replicating',
#  'digital',
#  'experience',
#  'physical',
#  'spacenin',
#  'addition',
#  'offering',
#  'free',
#  'gigabitspeed',
#  'wifi',
#  'domestic',
#  'calling',
#  'kiosk',
#  'includes',
#  'thirty',
#  'sensor',
#  'three',
#  'security',
#  'camera',
#  'according',
#  'linknyc',
#  'footage',
#  'camera',
#  'may',
#  'shared',
#  'law',
#  'enforcement',
#  'protect',
#  'safety',
#  'including',
#  'emergency',
#  'involving',
#  'potential',
#  'harm',
#  'instance',
#  'vandalismnon',
#  'monday',
#  'spokesperson',
#  'company',
#  'told',
#  'gothamist',
#  'vandal',
#  'spotted',
#  'one',
#  'security',
#  'camera',
#  'footage',
#  'shown',
#  'nypd',
#  'police',
#  'department',
#  'information',
#  'linknycbashing',
#  'related',
#  'arrestsnaccording',
#  'thomas',
#  'prolific',
#  'spree',
#  'seem',
#  'bit',
#  'scary',
#  'considering',
#  'likely',
#  'mean',
#  'determined',
#  'possibly',
#  'angry',
#  'individual',
#  'walking',
#  'around',
#  'city',
#  'sledgehammer',
#  'whatever',
#  'tool',
#  'destruction',
#  'usednat',
#  'time',
#  'noted',
#  'see',
#  'beautiful',
#  'thing',
#  'carnage',
#  'somebody',
#  'really',
#  'got',
#  'something',
#  'say',
#  'way',
#  'saying',
#  'keep',
#  'eye',
#  'inbox',
#  'manifestongothamist',
#  'part',
#  'wnyc',
#  'nonprofit',
#  'organization',
#  'relies',
#  'member',
#  'support',
#  'help',
#  'u',
#  'making',
#  'donation',
#  'todaynyour',
#  'contribution',
#  'support',
#  'local',
#  'new',
#  'york',
#  'coverage',
#  'gothamist',
#  'thank',
#  'youncontact',
#  'author',
#  'article',
#  'email',
#  'tipsgothamistcom',
#  'question',
#  'comment',
#  'tipsntwitternfacebooknredditnprintnhuman',
#  'uprising',
#  'linknyc',
#  'vandalismnplease',
#  'enable',
#  'javascript',
#  'view',
#  'comment',
#  'powered',
#  'disqusnbest',
#  'gothamistnthe',
#  'best',
#  'parm',
#  'sandwich',
#  'spot',
#  'nyc',
#  'best',
#  'eatin',
#  'movie',
#  'theater',
#  'nycthe',
#  'best',
#  'gothamist',
#  'best',
#  'bite',
#  'best',
#  'new',
#  'burger',
#  'nycnxcxa',
#  'wnyc',
#  'right',
#  'reservednterms',
#  'use',
#  'privacy',
#  'policy',
#  "'",
#  ',',
#  "'",
#  'p',
#  "'",
#  ',',
#  "'asvandal",
#  'smash',
#  'linknyc',
#  'screen',
#  'wifi',
#  'kiosk',
#  'across',
#  'city',
#  'xexx',
#  'cbs',
#  'new',
#  'yorknmenunsportsncbs',
#  'videoscbs',
#  'sport',
#  'livegiantsnew',
#  'york',
#  'giantsjetsnew',
#  'york',
#  'jetsyanksnew',
#  'york',
#  'yankeesmetsnew',
#  'york',
#  'metsknicksnew',
#  'york',
#  'knicksnetsnew',
#  'jersey',
#  'netsrangersnew',
#  'york',
#  'rangersdevilsislesoddsnvideoncbsn',
#  'new',
#  'yorkcbs',
#  'digital',
#  'featuresspecial',
#  'reportscbsn',
#  'cbs',
#  'newscbs',
#  'sport',
#  'livenewsweathersnap',
#  'shot',
#  'nychealth',
#  'fitnessthe',
#  'dig',
#  'elle',
#  'mcloganall',
#  'latest',
#  'videosnbest',
#  'ofnbest',
#  'oftraveltantillonmorencontests',
#  'promotionsphoto',
#  'galleriestravelentertainmentnnewsnall',
#  'newsnnew',
#  'yorkhealthwatchnew',
#  'jerseyconsumerconnecticutbusinessus',
#  'worldentertainmentpoliticstechoffbeat',
#  'oddonly',
#  'cbsnlatest',
#  'headlinesnbrooklyn',
#  'botanic',
#  'garden',
#  'host',
#  'annual',
#  'cherry',
#  'blossom',
#  'festival',
#  'weekendthe',
#  'annual',
#  'sakura',
#  'matsuri',
#  'festival',
#  'kick',
#  'weekend',
#  'celebrating',
#  'thing',
#  'japaneselifelike',
#  'sculpture',
#  'garnering',
#  'lot',
#  'attention',
#  'nj',
#  'townyou',
#  'may',
#  'doubletake',
#  'come',
#  'across',
#  'lifelike',
#  'sculpture',
#  'one',
#  'new',
#  'jersey',
#  'townngalleriesnvisiting',
#  'armourstiner',
#  'octagon',
#  'househidden',
#  'along',
#  'hudson',
#  'river',
#  'eightsided',
#  'house',
#  'fascinates',
#  'people',
#  'admire',
#  'odd',
#  'architecturenlatest',
#  'videonlatest',
#  'videonweathernweather',
#  'linksnlocal',
#  'radar',
#  'mapsny',
#  'nj',
#  'ct',
#  'school',
#  'closingsforecast',
#  'videoscbs',
#  'weather',
#  'appcbs',
#  'weather',
#  'watchersnmore',
#  'weathernweather',
#  'watchersnweather',
#  'videosnnew',
#  'york',
#  'weather',
#  'cbs',
#  'afternoon',
#  'weather',
#  'headlinescbss',
#  'john',
#  'elliott',
#  'forecast',
#  'hour',
#  'agonew',
#  'york',
#  'weather',
#  'sunny',
#  'warmcbss',
#  'john',
#  'elliott',
#  'latest',
#  'weather',
#  'forecast',
#  'hour',
#  'agonsportsnall',
#  'sportsncbs',
#  'videoscbs',
#  'sport',
#  'livegiantsnew',
#  'york',
#  'giantsjetsnew',
#  'york',
#  'jetsyanksnew',
#  'york',
#  'yankeesmetsnew',
#  'york',
#  'metsknicksnew',
#  'york',
#  'knicksnetsnew',
#  'jersey',
#  'netsrangersnew',
#  'york',
#  'rangersdevilsislesoddsnlatest',
#  'headlinesnbaseball',
#  'report',
#  'red',
#  'sox',
#  'turning',
#  'season',
#  'aroundthe',
#  'boston',
#  'red',
#  'sox',
#  'swept',
#  'threegame',
#  'series',
#  'al',
#  'eastleading',
#  'tampa',
#  'bay',
#  'ray',
#  'weekend',
#  'look',
#  'figuring',
#  'thing',
#  'outmri',
#  'mets',
#  'ace',
#  'degrom',
#  'come',
#  'back',
#  'clean',
#  'damagemets',
#  'ace',
#  'jacob',
#  'degrom',
#  'remains',
#  'track',
#  'start',
#  'friday',
#  'night',
#  'mri',
#  'right',
#  'elbow',
#  'showed',
#  'damagenvideonall',
#  'videosncbsn',
#  'new',
#  'yorkcbs',
#  'digital',
#  'featuresspecial',
#  'reportscbsn',
#  'cbs',
#  'newscbs',
#  'sport',
#  'livenewsweathersnap',
#  'shot',
#  'nychealth',
#  'fitnessthe',
#  'dig',
#  'elle',
#  'mcloganall',
#  'latest',
#  'videosnmore',
#  'videoncbsn',
#  'new',
#  'yorknewsweather',
#  'forecastsportsnbest',
#  'ofnlatest',
#  'headlinesnthe',
#  'armourstiner',
#  'house',
#  'octaganol',
#  'home',
#  'fascinates',
#  'architecture',
#  'fan',
#  'open',
#  'door',
#  'visitorsthe',
#  'house',
#  'one',
#  'u',
#  'home',
#  'built',
#  'octagonal',
#  'house',
#  'craze',
#  'started',
#  'year',
#  'agoxcxawhere',
#  'celebrate',
#  'earth',
#  'day',
#  'around',
#  'nyclooking',
#  'way',
#  'join',
#  'fellow',
#  'human',
#  'celebrate',
#  'living',
#  'better',
#  'balance',
#  'planet',
#  'here',
#  'list',
#  'start',
#  'asian',
#  'fusion',
#  'whats',
#  'trending',
#  'new',
#  'york',
#  'city',
#  'food',
#  'scenecurious',
#  'new',
#  'york',
#  'city',
#  'intheknow',
#  'crowd',
#  'eating',
#  'drinking',
#  'easy',
#  'spot',
#  'line',
#  'door',
#  'underlying',
#  'trend',
#  'harder',
#  'seehealthy',
#  'homemade',
#  'recipe',
#  'save',
#  'money',
#  'keep',
#  'dog',
#  'fitkeeping',
#  'dog',
#  'healthy',
#  'fit',
#  'important',
#  'long',
#  'happy',
#  'lifexcxachef',
#  'wenford',
#  'simpson',
#  'cook',
#  'islandthemed',
#  'easter',
#  'foodeaster',
#  'time',
#  'year',
#  'thats',
#  'deeply',
#  'connected',
#  'food',
#  'traditionsxcxathe',
#  'holiday',
#  'occasion',
#  'feasting',
#  'meal',
#  'usually',
#  'symbolic',
#  'meaningxcxafurry',
#  'friend',
#  'finder',
#  'manny',
#  'ralph',
#  'looking',
#  'forever',
#  'homesmanny',
#  'yearold',
#  'housebroken',
#  'maltipoo',
#  'mixnralph',
#  'monthsold',
#  'housebroken',
#  'pound',
#  'brazilnmorenstation',
#  'infonwcbstvwlnytvcontact',
#  'usadvertisecontestsstation',
#  'eventsntravelnfinal',
#  'four',
#  'guide',
#  'top',
#  'instagramworthy',
#  'spot',
#  'downtown',
#  'minneapoliswith',
#  'thousand',
#  'final',
#  'four',
#  'fan',
#  'heading',
#  'downtown',
#  'minneapolis',
#  'coming',
#  'day',
#  'better',
#  'believe',
#  'instagram',
#  'filter',
#  'flyingncbs',
#  'entertainmentncbs',
#  'entertainmentnlatest',
#  'photosnvisiting',
#  'armourstiner',
#  'octagon',
#  'househidden',
#  'along',
#  'hudson',
#  'river',
#  'eightsided',
#  'house',
#  'fascinates',
#  'people',
#  'admire',
#  'odd',
#  'architecturenicons',
#  'disruptors',
#  'podcastncbsn',
#  'new',
#  'yorkwatch',
#  'nownvandal',
#  'smash',
#  'linknyc',
#  'screen',
#  'wifi',
#  'kiosk',
#  'acrossxcxacitynapril',
#  'pmfiled',
#  'underaundrea',
#  'clinethomas',
#  'chelsea',
#  'linknyc',
#  'local',
#  'tv',
#  'manhattan',
#  'new',
#  'york',
#  'west',
#  'villagennew',
#  'york',
#  'cbsnewyork',
#  'xexx',
#  'two',
#  'dozen',
#  'linknyc',
#  'kiosk',
#  'vandalized',
#  'across',
#  'citynthe',
#  'kiosk',
#  'replaced',
#  'phone',
#  'booth',
#  'provide',
#  'free',
#  'wifi',
#  'calling',
#  'service',
#  'cbsxexxs',
#  'aundrea',
#  'clinethomas',
#  'reported',
#  'tuesdaynan',
#  'nypd',
#  'officer',
#  'took',
#  'picture',
#  'shattered',
#  'glass',
#  'kiosk',
#  'west',
#  'th',
#  'street',
#  'near',
#  'th',
#  'avenue',
#  'caution',
#  'tape',
#  'covered',
#  'another',
#  'damaged',
#  'one',
#  'streetnxexxcwhy',
#  'would',
#  'mean',
#  'theyxexxre',
#  'spending',
#  'lot',
#  'money',
#  'put',
#  'itxexxs',
#  'kind',
#  'convenientxexxd',
#  'said',
#  'sandra',
#  'brathwait',
#  'work',
#  'areanmore',
#  'two',
#  'dozen',
#  'linknyc',
#  'kiosk',
#  'vandalized',
#  'within',
#  'last',
#  'week',
#  'linknyc',
#  'say',
#  'impact',
#  'vulnerable',
#  'resident',
#  'httpstcowfcpdbds',
#  'cbsnewyork',
#  'pictwittercomigomkajnnxexx',
#  'aundrea',
#  'clinethomas',
#  'aclinethomas',
#  'april',
#  'naccording',
#  'linknyc',
#  'kiosk',
#  'targeted',
#  'mainly',
#  'west',
#  'village',
#  'neighborhood',
#  'chelsea',
#  'within',
#  'last',
#  'weeknxexxcit',
#  'seems',
#  'like',
#  'unnecessary',
#  'form',
#  'anger',
#  'bother',
#  'definitelyxexxd',
#  'west',
#  'village',
#  'resident',
#  'david',
#  'hutchings',
#  'saidnon',
#  'friday',
#  'mohammed',
#  'islam',
#  'fruit',
#  'stand',
#  'corner',
#  'th',
#  'street',
#  'th',
#  'avenue',
#  'said',
#  'heard',
#  'loud',
#  'crash',
#  'kiosk',
#  'step',
#  'away',
#  'said',
#  'saw',
#  'suspect',
#  'man',
#  'throw',
#  'large',
#  'stone',
#  'screen',
#  'broad',
#  'daylightnxexxca',
#  'lot',
#  'people',
#  'see',
#  'xexxa',
#  'broke',
#  'one',
#  'goxexxd',
#  'islam',
#  'saidnislam',
#  'said',
#  'screen',
#  'question',
#  'since',
#  'fixednwitnesses',
#  'called',
#  'police',
#  'discovered',
#  'string',
#  'vandalism',
#  'unit',
#  'installed',
#  'replace',
#  'pay',
#  'phone',
#  'give',
#  'access',
#  'city',
#  'servicesnxexxcit',
#  'give',
#  'free',
#  'public',
#  'wifi',
#  'give',
#  'charge',
#  'phonexexxd',
#  'said',
#  'john',
#  'ponessa',
#  'work',
#  'chelseanyikes',
#  'somebody',
#  'went',
#  'around',
#  'village',
#  'smashing',
#  'linknyc',
#  'screen',
#  'pictwittercomswdtwltinxexx',
#  'josh',
#  'machiz',
#  'machiz',
#  'april',
#  'nthe',
#  'kiosk',
#  'received',
#  'backlash',
#  'place',
#  'homeless',
#  'camp',
#  'others',
#  'use',
#  'wifi',
#  'watch',
#  'pornography',
#  ...]

# %%
dictionary = gensim.corpora.Dictionary([d.split() for d in preprocess_text])

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in[d.split() for d in preprocess_text]]

# %%
# for i in range(len(bow_doc_x)):
#     print("Word {} (\"{}\") appears {} time.".format(bow_doc_x[i][0], 
#                                                      dictionary[bow_doc_x[i][0]], 
#                                                      bow_doc_x[i][1]))

# %%
lda_model =  gensim.models.LdaMulticore(bow_corpus, 
                                   num_topics = 8, 
                                   id2word = dictionary,                                    
                                   passes = 10,
                                   workers = 2)

# %%
topics = lda_model.print_topics(num_words=4)
for topic in topics:
    print(topic)
# Out:
# (0, '0.060*"york" + 0.046*"free" + 0.026*"use" + 0.021*"say"')
# (1, '0.037*"public" + 0.024*"also" + 0.015*"could" + 0.015*"security"')
# (2, '0.092*"city" + 0.059*"kiosk" + 0.035*"\'" + 0.028*"user"')
# (3, '0.037*"network" + 0.030*"said" + 0.026*"internet" + 0.024*"one"')
# (4, '0.057*"wifi" + 0.041*"service" + 0.026*"data" + 0.018*"company"')
# (5, '0.024*"xexx" + 0.023*"technology" + 0.022*"device" + 0.017*"need"')
# (6, '0.065*"linknyc" + 0.032*"link" + 0.026*"privacy" + 0.025*"access"')
# (7, '0.106*"new" + 0.031*"people" + 0.025*"," + 0.022*"make"')
